# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
H = 10
M_values = np.arange(5, 31, 5)

# %%
r_star_J_avg_exp_values = np.load("r_star_J_avg_exp_values.npy")
r_star_x_max_norm_values = np.load("r_star_x_max_norm_values.npy")
mw_J_avg_exp_values = np.load("mw_J_avg_exp_values.npy")
mw_x_max_norm_values = np.load("mw_x_max_norm_values.npy")

# %%
wp_J_avg_exp_values = np.load("wp_J_avg_exp_values.npy")
wp_x_max_norm_values = np.load("wp_x_max_norm_values.npy")

# %%
wi_J_avg_exp_values = np.load("wi_J_avg_exp_values.npy")
wi_x_max_norm_values = np.load("wi_x_max_norm_values.npy")

# %%
mwa_J_avg_exp_values = np.load("mwa_J_avg_exp_values.npy")
mwa_x_max_norm_values = np.load("mwa_x_max_norm_values.npy")

# %%
dpp_J_avg_exp_values = np.load("dpp_J_avg_exp_values.npy")
dpp_x_max_norm_values = np.load("dpp_x_max_norm_values.npy")

# %%
ld_J_avg_exp_values = np.load("ld_J_avg_exp_values.npy")
ld_x_max_norm_values = np.load("ld_x_max_norm_values.npy")

# %%
plt.figure()
plt.title("Exp Weighted Sum AoI Comparison for vp=0")
plt.plot(M_values, r_star_J_avg_exp_values[0], color='r', linestyle='dashed', label='R*', marker="v")
plt.plot(M_values, mw_J_avg_exp_values[0], color='b', linestyle='dashed', label='MW', marker="o")
#plt.plot(M_values, dpp_J_avg_exp_values[0], color='c', linestyle='dashed', label='DPP', marker="<")
plt.plot(M_values, wi_J_avg_exp_values[0], color='k', linestyle='dashed', label='WI w/ TP', marker="^")
plt.plot(M_values, mwa_J_avg_exp_values[0], color='y', linestyle='dashed', label='MWA', marker="d")
plt.plot(M_values, wp_J_avg_exp_values[0], color='g', linestyle='dashed', label='WI w/o TP', marker="x")
#plt.plot(M_values, ld_J_avg_exp_values[0], color='m', linestyle='dashed', label='LD', marker="+")
plt.legend()
plt.xlabel("Number of nodes, M")
plt.ylabel("Expected Weighted Sum AoI")

plt.figure()
plt.title("Max Norm Throughput Debt Comparison for vp=0")
plt.plot(M_values, r_star_x_max_norm_values[0], color='r', linestyle='dashed', label='R*', marker="v")
plt.plot(M_values, mw_x_max_norm_values[0], color='b', linestyle='dashed', label='MW', marker="o")
#plt.plot(M_values, dpp_x_max_norm_values[0], color='c', linestyle='dashed', label='DPP', marker="<")
plt.plot(M_values, wi_x_max_norm_values[0], color='k', linestyle='dashed', label='WI w/ TP', marker="^")
plt.plot(M_values, mwa_x_max_norm_values[0], color='y', linestyle='dashed', label='MWA', marker="d")
plt.plot(M_values, wp_x_max_norm_values[0], color='g', linestyle='dashed', label='WI w/o TP', marker="x")
#plt.plot(M_values, ld_x_max_norm_values[0], color='m', linestyle='dashed', label='LD', marker="+")
plt.legend()
plt.xlabel("Number of nodes, M")
plt.ylabel("Max Normalized Throughput Debt")
# Out:
# Text(0, 0.5, 'Max Normalized Throughput Debt')

# %%
plt.figure()
plt.title("Exp Weighted Sum AoI Comparison for vp=0.005")
plt.plot(M_values, r_star_J_avg_exp_values[1], color='r', linestyle='dashed', label='R*', marker="v")
plt.plot(M_values, mw_J_avg_exp_values[1], color='b', linestyle='dashed', label='MW', marker="o")
#plt.plot(M_values, dpp_J_avg_exp_values[1], color='c', linestyle='dashed', label='DPP', marker="<")
plt.plot(M_values, wi_J_avg_exp_values[1], color='k', linestyle='dashed', label='WI w/ TP', marker="^")
plt.plot(M_values, mwa_J_avg_exp_values[1], color='y', linestyle='dashed', label='MWA', marker="d")
plt.plot(M_values, wp_J_avg_exp_values[1], color='g', linestyle='dashed', label='WI w/o TP', marker="x")
#plt.plot(M_values, ld_J_avg_exp_values[1], color='m', linestyle='dashed', label='LD', marker="+")
plt.legend()
plt.xlabel("Number of nodes, M")
plt.ylabel("Expected Weighted Sum AoI")

plt.figure()
plt.title("Max Norm Throughput Debt Comparison for vp=0.005")
plt.plot(M_values, r_star_x_max_norm_values[1], color='r', linestyle='dashed', label='R*', marker="v")
plt.plot(M_values, mw_x_max_norm_values[1], color='b', linestyle='dashed', label='MW', marker="o")
#plt.plot(M_values, dpp_x_max_norm_values[1], color='c', linestyle='dashed', label='DPP', marker="<")
plt.plot(M_values, wi_x_max_norm_values[1], color='k', linestyle='dashed', label='WI w/ TP', marker="^")
plt.plot(M_values, mwa_x_max_norm_values[1], color='y', linestyle='dashed', label='MWA', marker="d")
plt.plot(M_values, wp_x_max_norm_values[1], color='g', linestyle='dashed', label='WI w/o TP', marker="x")
#plt.plot(M_values, ld_x_max_norm_values[1], color='m', linestyle='dashed', label='LD', marker="+")
plt.legend()
plt.xlabel("Number of nodes, M")
plt.ylabel("Max Normalized Throughput Debt")
# Out:
# Text(0, 0.5, 'Max Normalized Throughput Debt')

# %%
plt.figure()
plt.title("Exp Weighted Sum AoI Comparison for vp=0.01")
plt.plot(M_values, r_star_J_avg_exp_values[2], color='r', linestyle='dashed', label='R*', marker="v")
plt.plot(M_values, mw_J_avg_exp_values[2], color='b', linestyle='dashed', label='MW', marker="o")
#plt.plot(M_values, dpp_J_avg_exp_values[2], color='c', linestyle='dashed', label='DPP', marker="<")
plt.plot(M_values, wi_J_avg_exp_values[2], color='k', linestyle='dashed', label='WI w/ TP', marker="^")
plt.plot(M_values, mwa_J_avg_exp_values[2], color='y', linestyle='dashed', label='MWA', marker="d")
plt.plot(M_values, wp_J_avg_exp_values[2], color='g', linestyle='dashed', label='WI w/o TP', marker="x")
#plt.plot(M_values, ld_J_avg_exp_values[2], color='m', linestyle='dashed', label='LD', marker="+")
plt.legend()
plt.xlabel("Number of nodes, M")
plt.ylabel("Expected Weighted Sum AoI")

plt.figure()
plt.title("Max Norm Throughput Debt Comparison for vp=0.01")
plt.plot(M_values, r_star_x_max_norm_values[2], color='r', linestyle='dashed', label='R*', marker="v")
plt.plot(M_values, mw_x_max_norm_values[2], color='b', linestyle='dashed', label='MW', marker="o")
#plt.plot(M_values, dpp_x_max_norm_values[2], color='c', linestyle='dashed', label='DPP', marker="<")
plt.plot(M_values, wi_x_max_norm_values[2], color='k', linestyle='dashed', label='WI w/ TP', marker="^")
plt.plot(M_values, mwa_x_max_norm_values[2], color='y', linestyle='dashed', label='MWA', marker="d")
plt.plot(M_values, wp_x_max_norm_values[2], color='g', linestyle='dashed', label='WI w/o TP', marker="x")
#plt.plot(M_values, ld_x_max_norm_values[2], color='m', linestyle='dashed', label='LD', marker="+")
plt.legend()
plt.xlabel("Number of nodes, M")
plt.ylabel("Max Normalized Throughput Debt")
# Out:
# Text(0, 0.5, 'Max Normalized Throughput Debt')

# %%
plt.figure()
plt.title("Exp Weighted Sum AoI Comparison for vp=0.02")
plt.plot(M_values, r_star_J_avg_exp_values[3], color='r', linestyle='dashed', label='R*', marker="v")
plt.plot(M_values, mw_J_avg_exp_values[3], color='b', linestyle='dashed', label='MW', marker="o")
#plt.plot(M_values, dpp_J_avg_exp_values[3], color='c', linestyle='dashed', label='DPP', marker="<")
plt.plot(M_values, wi_J_avg_exp_values[3], color='k', linestyle='dashed', label='WI w/ TP', marker="^")
plt.plot(M_values, mwa_J_avg_exp_values[3], color='y', linestyle='dashed', label='MWA', marker="d")
plt.plot(M_values, wp_J_avg_exp_values[3], color='g', linestyle='dashed', label='WI w/o TP', marker="x")
#plt.plot(M_values, ld_J_avg_exp_values[3], color='m', linestyle='dashed', label='LD', marker="+")
plt.legend()
plt.xlabel("Number of nodes, M")
plt.ylabel("Expected Weighted Sum AoI")

plt.figure()
plt.title("Max Norm Throughput Debt Comparison for vp=0.02")
plt.plot(M_values, r_star_x_max_norm_values[3], color='r', linestyle='dashed', label='R*', marker="v")
plt.plot(M_values, mw_x_max_norm_values[3], color='b', linestyle='dashed', label='MW', marker="o")
#plt.plot(M_values, dpp_x_max_norm_values[3], color='c', linestyle='dashed', label='DPP', marker="<")
plt.plot(M_values, wi_x_max_norm_values[3], color='k', linestyle='dashed', label='WI w/ TP', marker="^")
plt.plot(M_values, mwa_x_max_norm_values[3], color='y', linestyle='dashed', label='MWA', marker="d")
plt.plot(M_values, wp_x_max_norm_values[3], color='g', linestyle='dashed', label='WI w/o TP', marker="x")
#plt.plot(M_values, ld_x_max_norm_values[3], color='m', linestyle='dashed', label='LD', marker="+")
plt.legend()
plt.xlabel("Number of nodes, M")
plt.ylabel("Max Normalized Throughput Debt")
# Out:
# Text(0, 0.5, 'Max Normalized Throughput Debt')

# %%
plt.figure()
plt.title("Exp Weighted Sum AoI Comparison for R*")
plt.plot(M_values, r_star_J_avg_exp_values[0,:], color='y', linestyle='dashed', label='vp=0', marker="x")
plt.plot(M_values, r_star_J_avg_exp_values[1,:], color='r', linestyle='dashed', label='vp=0.005', marker="v")
plt.plot(M_values, r_star_J_avg_exp_values[2,:], color='b', linestyle='dashed', label='vp=0.01', marker="o")
plt.plot(M_values, r_star_J_avg_exp_values[3,:], color='c', linestyle='dashed', label='vp=0.02', marker="<")
plt.legend()
plt.xlabel("Number of nodes, M")
plt.ylabel("Expected Weighted Sum AoI")

plt.figure()
plt.title("Max Norm Throughput Debt Comparison for R*")
plt.plot(M_values, r_star_x_max_norm_values[0,:], color='y', linestyle='dashed', label='vp=0', marker="x")
plt.plot(M_values, r_star_x_max_norm_values[1,:], color='r', linestyle='dashed', label='vp=0.005', marker="v")
plt.plot(M_values, r_star_x_max_norm_values[2,:], color='b', linestyle='dashed', label='vp=0.01', marker="o")
plt.plot(M_values, r_star_x_max_norm_values[3,:], color='c', linestyle='dashed', label='vp=0.02', marker="<")
plt.legend()
plt.xlabel("Number of nodes, M")
plt.ylabel("Max Normalized Throughput Debt")
# Out:
# Text(0, 0.5, 'Max Normalized Throughput Debt')

# %%
plt.figure()
plt.title("Exp Weighted Sum AoI Comparison for MW")
plt.plot(M_values, mw_J_avg_exp_values[0,:], color='y', linestyle='dashed', label='vp=0', marker="x")
plt.plot(M_values, mw_J_avg_exp_values[1,:], color='r', linestyle='dashed', label='vp=0.005', marker="v")
plt.plot(M_values, mw_J_avg_exp_values[2,:], color='b', linestyle='dashed', label='vp=0.01', marker="o")
plt.plot(M_values, mw_J_avg_exp_values[3,:], color='c', linestyle='dashed', label='vp=0.02', marker="<")
plt.legend()
plt.xlabel("Number of nodes, M")
plt.ylabel("Expected Weighted Sum AoI")

plt.figure()
plt.title("Max Norm Throughput Debt Comparison for MW")
plt.plot(M_values, mw_x_max_norm_values[0,:], color='y', linestyle='dashed', label='vp=0', marker="x")
plt.plot(M_values, mw_x_max_norm_values[1,:], color='r', linestyle='dashed', label='vp=0.005', marker="v")
plt.plot(M_values, mw_x_max_norm_values[2,:], color='b', linestyle='dashed', label='vp=0.01', marker="o")
plt.plot(M_values, mw_x_max_norm_values[3,:], color='c', linestyle='dashed', label='vp=0.02', marker="<")
plt.legend()
plt.xlabel("Number of nodes, M")
plt.ylabel("Max Normalized Throughput Debt")
# Out:
# Text(0, 0.5, 'Max Normalized Throughput Debt')

# %%
plt.figure()
plt.title("Exp Weighted Sum AoI Comparison for WI")
plt.plot(M_values, wi_J_avg_exp_values[0,:], color='y', linestyle='dashed', label='vp=0', marker="x")
plt.plot(M_values, wi_J_avg_exp_values[1,:], color='r', linestyle='dashed', label='vp=0.005', marker="v")
plt.plot(M_values, wi_J_avg_exp_values[2,:], color='b', linestyle='dashed', label='vp=0.01', marker="o")
plt.plot(M_values, wi_J_avg_exp_values[3,:], color='c', linestyle='dashed', label='vp=0.02', marker="<")
plt.legend()
plt.xlabel("Number of nodes, M")
plt.ylabel("Expected Weighted Sum AoI")

plt.figure()
plt.title("Max Norm Throughput Debt Comparison for WI")
plt.plot(M_values, wi_x_max_norm_values[0,:], color='y', linestyle='dashed', label='vp=0', marker="x")
plt.plot(M_values, wi_x_max_norm_values[1,:], color='r', linestyle='dashed', label='vp=0.005', marker="v")
plt.plot(M_values, wi_x_max_norm_values[2,:], color='b', linestyle='dashed', label='vp=0.01', marker="o")
plt.plot(M_values, wi_x_max_norm_values[3,:], color='c', linestyle='dashed', label='vp=0.02', marker="<")
plt.legend()
plt.xlabel("Number of nodes, M")
plt.ylabel("Max Normalized Throughput Debt")
# Out:
# Text(0, 0.5, 'Max Normalized Throughput Debt')

# %%
plt.figure()
plt.title("Exp Weighted Sum AoI Comparison for WP")
plt.plot(M_values, wp_J_avg_exp_values[0,:], color='y', linestyle='dashed', label='vp=0', marker="x")
plt.plot(M_values, wp_J_avg_exp_values[1,:], color='r', linestyle='dashed', label='vp=0.005', marker="v")
plt.plot(M_values, wp_J_avg_exp_values[2,:], color='b', linestyle='dashed', label='vp=0.01', marker="o")
plt.plot(M_values, wp_J_avg_exp_values[3,:], color='c', linestyle='dashed', label='vp=0.02', marker="<")
plt.legend()
plt.xlabel("Number of nodes, M")
plt.ylabel("Expected Weighted Sum AoI")

plt.figure()
plt.title("Max Norm Throughput Debt Comparison for WP")
plt.plot(M_values, wp_x_max_norm_values[0,:], color='y', linestyle='dashed', label='vp=0', marker="x")
plt.plot(M_values, wp_x_max_norm_values[1,:], color='r', linestyle='dashed', label='vp=0.005', marker="v")
plt.plot(M_values, wp_x_max_norm_values[2,:], color='b', linestyle='dashed', label='vp=0.01', marker="o")
plt.plot(M_values, wp_x_max_norm_values[3,:], color='c', linestyle='dashed', label='vp=0.02', marker="<")
plt.legend()
plt.xlabel("Number of nodes, M")
plt.ylabel("Max Normalized Throughput Debt")
# Out:
# Text(0, 0.5, 'Max Normalized Throughput Debt')

# %%
plt.figure()
plt.title("Exp Weighted Sum AoI Comparison for WI")
plt.plot(M_values, wi_J_avg_exp_values[0,:], color='y', linestyle='dashed', label='vp=0', marker="x")
plt.plot(M_values, wi_J_avg_exp_values[1,:], color='r', linestyle='dashed', label='vp=0.005', marker="v")
plt.plot(M_values, wi_J_avg_exp_values[2,:], color='b', linestyle='dashed', label='vp=0.01', marker="o")
plt.plot(M_values, wi_J_avg_exp_values[3,:], color='c', linestyle='dashed', label='vp=0.02', marker="<")
plt.legend()
plt.xlabel("Number of nodes, M")
plt.ylabel("Expected Weighted Sum AoI")

plt.figure()
plt.title("Max Norm Throughput Debt Comparison for WI")
plt.plot(M_values, wi_x_max_norm_values[0,:], color='y', linestyle='dashed', label='vp=0', marker="x")
plt.plot(M_values, wi_x_max_norm_values[1,:], color='r', linestyle='dashed', label='vp=0.005', marker="v")
plt.plot(M_values, wi_x_max_norm_values[2,:], color='b', linestyle='dashed', label='vp=0.01', marker="o")
plt.plot(M_values, wi_x_max_norm_values[3,:], color='c', linestyle='dashed', label='vp=0.02', marker="<")
plt.legend()
plt.xlabel("Number of nodes, M")
plt.ylabel("Max Normalized Throughput Debt")
# Out:
# Text(0, 0.5, 'Max Normalized Throughput Debt')

# %%
wi_J_avg_exp_values
# Out:
# array([[ 4.41670094,  9.13378222, 14.18921206, 19.69660411, 25.55501171,
#         31.55389919],
#        [ 5.57878315, 10.66714167, 16.07619387, 21.39893298, 26.31289336,
#         31.49501939],
#        [ 5.27054928,  9.90046317, 14.74758911, 19.48286373, 24.12721095,
#         28.8868349 ],
#        [ 5.18310939,  9.68964838, 14.0920245 , 18.40667768, 22.75034663,
#         27.06835695]])

# %%
wp_J_avg_exp_values - wi_J_avg_exp_values
# Out:
# array([[-0.09771998, -0.06617219, -0.00902685, -0.03198635, -0.12140847,
#         -0.06994704],
#        [-0.01610827, -0.07148823, -0.1323967 , -0.04264989, -0.0095329 ,
#         -0.08863526],
#        [-0.00511105, -0.04972008, -0.03742585, -0.01423144, -0.03963615,
#         -0.02595137],
#        [-0.02119038, -0.04417798, -0.01842117, -0.03599264, -0.04652096,
#         -0.07567907]])
